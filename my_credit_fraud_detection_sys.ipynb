# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("creditcard.csv")

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
# original data has been converted to view using pca to anonymise

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.nunique()
# Out:
# Time      124592
# V1        275663
# V2        275663
# V3        275663
# V4        275663
# V5        275663
# V6        275663
# V7        275663
# V8        275663
# V9        275663
# V10       275663
# V11       275663
# V12       275663
# V13       275663
# V14       275663
# V15       275663
# V16       275663
# V17       275663
# V18       275663
# V19       275663
# V20       275663
# V21       275663
# V22       275663
# V23       275663
# V24       275663
# V25       275663
# V26       275663
# V27       275663
# V28       275663
# Amount     32767
# Class          2
# dtype: int64

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.175161e-15  3.384974e-16 -1.379537e-15  2.094852e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.021879e-15  1.494498e-15 -5.620335e-16  1.149614e-16 -2.414189e-15
# ...

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %% [markdown]
# ## Scaling data

# %%
# amount column was not scaled

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
df["Amount"]=sc.fit_transform(pd.DataFrame(df["Amount"]))

# %% [markdown]
# ## Visualisations

# %%
for i in df.columns:
    sns.boxplot(x= df[i])
    plt.show()

# %%
df.hist(figsize=(30,30))
# Out:
# array([[<Axes: title={'center': 'Time'}>, <Axes: title={'center': 'V1'}>,
#         <Axes: title={'center': 'V2'}>, <Axes: title={'center': 'V3'}>,
#         <Axes: title={'center': 'V4'}>, <Axes: title={'center': 'V5'}>],
#        [<Axes: title={'center': 'V6'}>, <Axes: title={'center': 'V7'}>,
#         <Axes: title={'center': 'V8'}>, <Axes: title={'center': 'V9'}>,
#         <Axes: title={'center': 'V10'}>, <Axes: title={'center': 'V11'}>],
#        [<Axes: title={'center': 'V12'}>, <Axes: title={'center': 'V13'}>,
#         <Axes: title={'center': 'V14'}>, <Axes: title={'center': 'V15'}>,
#         <Axes: title={'center': 'V16'}>, <Axes: title={'center': 'V17'}>],
#        [<Axes: title={'center': 'V18'}>, <Axes: title={'center': 'V19'}>,
#         <Axes: title={'center': 'V20'}>, <Axes: title={'center': 'V21'}>,
#         <Axes: title={'center': 'V22'}>, <Axes: title={'center': 'V23'}>],
#        [<Axes: title={'center': 'V24'}>, <Axes: title={'center': 'V25'}>,
# ...

# %%
X = df.drop('Class',axis=1)
y = df['Class']

# %%
X
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V20       V21  \
# ...

# %%
df1=pd.Series(df[df['Class']==1]['Amount']) #fraud
df2=pd.Series(df[df['Class']==0]['Amount']) # not fraud
df3=df2-df1

# %%
df1
# Out:
# 541      -0.353229
# 623       1.761758
# 4920      0.606031
# 6108     -0.117342
# 6329     -0.349231
#             ...
# 279863    1.206024
# 280143   -0.350191
# 280149   -0.041818
# 281144    0.626302
# 281674   -0.183191
# Name: Amount, Length: 492, dtype: float64

# %%
lines = df1.plot.line()

# %%
lines = df2.plot.line()

# %%
df4=pd.Series(df[df['Class']==1]['Time'])
df5=pd.Series(df[df['Class']==0]['Time'])
df6=df5-df4

# %%
lines = df4.plot.line()

# %%
lines = df5.plot.line()

# %%
data =df.corr()

# %%
plt.figure(figsize=(20,20))
sns.heatmap(data.iloc[:15,:32].corr(),cmap="YlGnBu", annot=True)
# Out:
# <Axes: >

# %%
y.hist(figsize =  (30,30))
# Out:
# <Axes: >

# %%
# data is imbalanced

# %% [markdown]
# ## Model selection

# %% [markdown]
# ### train test split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size = 0.7,random_state=0)

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((199364, 30), (199364,), (85443, 30), (85443,))

# %%
y_train.value_counts()
# Out:
# Class
# 0    199019
# 1       345
# Name: count, dtype: int64

# %%
#imbalanced

# %% [markdown]
# ### **Random forest**

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %% [markdown]
# ### Under sampling

# %%
# %pip install imblearn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from imblearn.under_sampling import NearMiss

# %%
pip install --upgrade imbalanced-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Implementing Undersampling for Handling Imbalanced
nm = NearMiss()
X_train_us,y_train_us=nm.fit_resample(X_train,y_train)

# %%
from collections import Counter
print("The number of classes before fit{}".format(Counter(y_train)))
print("The number of classes after fit{}".format(Counter(y_train_us)))
# Out:
# The number of classes before fitCounter({0: 199019, 1: 345})
# The number of classes after fitCounter({0: 345, 1: 345})

# %%
rf = RandomForestClassifier()
rf.fit(X_train_us,y_train_us)
# Out:
# RandomForestClassifier()

# %%
y_pred_us = rf.predict(X_test)

# %%
print(confusion_matrix(y_test,y_pred_us))
print(accuracy_score(y_test,y_pred_us))
print(classification_report(y_test,y_pred_us))
# Out:
# [[82637  2659]
#  [   15   132]]
# 0.9687042823870885
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98     85296
#            1       0.05      0.90      0.09       147
#
#     accuracy                           0.97     85443
#    macro avg       0.52      0.93      0.54     85443
# weighted avg       1.00      0.97      0.98     85443

# %%
list1 = []
for i in range(1,85444):
  list1.append(i)

# %%
plt.figure(figsize=(20,4))
plt.plot(list1, y_pred_us, label = "y_pred")
plt.plot(list1, y_test, label = "y_test")
plt.legend()
plt.show()

# %% [markdown]
# ### Over sampling

# %%
from imblearn.over_sampling import RandomOverSampler
os=RandomOverSampler()
X_train_os, y_train_os = os.fit_resample(X_train, y_train)

# %%
print("The number of classes before fit{}".format(Counter(y_train)))
print("The number of classes after fit{}".format(Counter(y_train_os)))
# Out:
# The number of classes before fitCounter({0: 199019, 1: 345})
# The number of classes after fitCounter({0: 199019, 1: 199019})

# %%
rf.fit(X_train_os,y_train_os)
y_pred_os = rf.predict(X_test)

# %%
print(confusion_matrix(y_test,y_pred_os))
print(accuracy_score(y_test,y_pred_os))
print(classification_report(y_test,y_pred_os))
# Out:
# [[85291     5]
#  [   34   113]]
# 0.9995435553526912
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85296
#            1       0.96      0.77      0.85       147
#
#     accuracy                           1.00     85443
#    macro avg       0.98      0.88      0.93     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
plt.figure(figsize=(20,4))
plt.plot(list1, y_pred_os, label = "y_pred")
plt.plot(list1, y_test, label = "y_test")
plt.legend()
plt.show()

# %% [markdown]
# ### SMOTE

# %%
X_train                                                    # SMOTE is an oversampling technique where the synthetic samples are generated for the minority class
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 161145  113921.0 -0.132066  0.107044 -0.650588 -0.996032  1.814333  1.740740
# 204520  135319.0  2.125994  0.014207 -1.514760  0.115021  0.598510 -0.333235
# 182659  125498.0 -0.086694  0.166240  1.573127  0.687266  0.222359  1.102606
# 25117    33520.0  1.352339 -0.534984  0.555143 -0.629355 -1.144170 -0.852967
# 227642  145152.0 -1.526760  0.647782  0.615391 -0.561114  0.836950 -0.514251
# ...          ...       ...       ...       ...       ...       ...       ...
# 211543  138459.0 -1.321976  1.138686 -0.940861  0.154160  0.109802 -0.538822
# 86293    61167.0 -0.627810  0.918729  1.478453  0.213171  0.933695  1.261486
# 122579   76616.0  1.512602 -0.949435 -0.219062 -1.638850 -0.856348 -0.465996
# 152315   97253.0  1.798863 -1.699791 -0.142182 -0.619533 -1.570248  0.083268
# 117952   74887.0 -0.589400  0.747828  1.784781  0.899612  0.257067 -0.001301
#
# ...

# %%
from imblearn.over_sampling import SMOTE

# %%
sm = SMOTE()
X_train_s, y_train_s = sm.fit_resample(X_train, y_train)
print("The number of classes before fit{}".format(Counter(y_train)))
print("The number of classes after fit{}".format(Counter(y_train_s)))
# Out:
# The number of classes before fitCounter({0: 199019, 1: 345})
# The number of classes after fitCounter({0: 199019, 1: 199019})

# %%
rf.fit(X_train_s,y_train_s)
y_pred_s = rf.predict(X_test)

# %%
print(confusion_matrix(y_test,y_pred_s))
print(accuracy_score(y_test,y_pred_s))
print(classification_report(y_test,y_pred_s))
# Out:
# [[85282    14]
#  [   27   120]]
# 0.9995201479348805
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85296
#            1       0.90      0.82      0.85       147
#
#     accuracy                           1.00     85443
#    macro avg       0.95      0.91      0.93     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
plt.figure(figsize=(20,4))
plt.plot(list1, y_pred_s, label = "y_pred")
plt.plot(list1, y_test, label = "y_test")
plt.legend()
plt.show()

# %%
import pickle #to serialize an object
with open('trained_card.sav', 'wb') as f:
    pickle.dump(rf, f)
